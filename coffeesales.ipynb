# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
 df = pd.read_csv("Coffe_sales.csv")

# %%
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      card  38.70          Latte     Morning     Fri
# 1              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      card  28.90      Americano   Afternoon     Fri
# 4              13      card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      card  35.76     Cappuccino     Morning     Sun
# 3543           14      card  35.76          Cocoa   Afternoon     Sun
# 3544           14      card  35.76          Cocoa   Afternoon     Sun
# 3545           15      card  25.96      Americano   Afternoon     Sun
# 3546           18      card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort        Date             Time
# ...

# %%
df.head()
# Out:
#    hour_of_day cash_type  money    coffee_name Time_of_Day Weekday Month_name  \
# 0           10      card   38.7          Latte     Morning     Fri        Mar
# 1           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 2           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 3           13      card   28.9      Americano   Afternoon     Fri        Mar
# 4           13      card   38.7          Latte   Afternoon     Fri        Mar
#
#    Weekdaysort  Monthsort        Date             Time
# 0            5          3  2024-03-01  10:15:50.520000
# 1            5          3  2024-03-01  12:19:22.539000
# 2            5          3  2024-03-01  12:20:18.089000
# 3            5          3  2024-03-01  13:46:33.006000
# 4            5          3  2024-03-01  13:48:14.626000

# %%
df.tail()
# Out:
#       hour_of_day cash_type  money coffee_name Time_of_Day Weekday Month_name  \
# 3542           10      card  35.76  Cappuccino     Morning     Sun        Mar
# 3543           14      card  35.76       Cocoa   Afternoon     Sun        Mar
# 3544           14      card  35.76       Cocoa   Afternoon     Sun        Mar
# 3545           15      card  25.96   Americano   Afternoon     Sun        Mar
# 3546           18      card  35.76       Latte       Night     Sun        Mar
#
#       Weekdaysort  Monthsort        Date             Time
# 3542            7          3  2025-03-23  10:34:54.894000
# 3543            7          3  2025-03-23  14:43:37.362000
# 3544            7          3  2025-03-23  14:44:16.864000
# 3545            7          3  2025-03-23  15:47:28.723000
# 3546            7          3  2025-03-23  18:11:38.635000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3547 entries, 0 to 3546
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour_of_day  3547 non-null   int64
#  1   cash_type    3547 non-null   object
#  2   money        3547 non-null   float64
#  3   coffee_name  3547 non-null   object
#  4   Time_of_Day  3547 non-null   object
#  5   Weekday      3547 non-null   object
#  6   Month_name   3547 non-null   object
#  7   Weekdaysort  3547 non-null   int64
#  8   Monthsort    3547 non-null   int64
#  9   Date         3547 non-null   object
#  10  Time         3547 non-null   object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 304.9+ KB

# %%
df.describe()
# Out:
#        hour_of_day        money  Weekdaysort    Monthsort
# count  3547.000000  3547.000000  3547.000000  3547.000000
# mean     14.185791    31.645216     3.845785     6.453905
# std       4.234010     4.877754     1.971501     3.500754
# min       6.000000    18.120000     1.000000     1.000000
# 25%      10.000000    27.920000     2.000000     3.000000
# 50%      14.000000    32.820000     4.000000     7.000000
# 75%      18.000000    35.760000     6.000000    10.000000
# max      22.000000    38.700000     7.000000    12.000000

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3547 entries, 0 to 3546
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   hour_of_day  3547 non-null   int64
#  1   cash_type    3547 non-null   object
#  2   money        3547 non-null   float64
#  3   coffee_name  3547 non-null   object
#  4   Time_of_Day  3547 non-null   object
#  5   Weekday      3547 non-null   object
#  6   Month_name   3547 non-null   object
#  7   Weekdaysort  3547 non-null   int64
#  8   Monthsort    3547 non-null   int64
#  9   Date         3547 non-null   datetime64[ns]
#  10  Time         3547 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 304.9+ KB

# %%
df['cash_type'] = df['cash_type'].str.capitalize()

# %%
df
# Out:
#       hour_of_day cash_type  money    coffee_name Time_of_Day Weekday  \
# 0              10      Card  38.70          Latte     Morning     Fri
# 1              12      Card  38.70  Hot Chocolate   Afternoon     Fri
# 2              12      Card  38.70  Hot Chocolate   Afternoon     Fri
# 3              13      Card  28.90      Americano   Afternoon     Fri
# 4              13      Card  38.70          Latte   Afternoon     Fri
# ...           ...       ...    ...            ...         ...     ...
# 3542           10      Card  35.76     Cappuccino     Morning     Sun
# 3543           14      Card  35.76          Cocoa   Afternoon     Sun
# 3544           14      Card  35.76          Cocoa   Afternoon     Sun
# 3545           15      Card  25.96      Americano   Afternoon     Sun
# 3546           18      Card  35.76          Latte       Night     Sun
#
#      Month_name  Weekdaysort  Monthsort       Date             Time
# ...

# %%
df["coffee_name"].unique()
# Out:
# array(['Latte', 'Hot Chocolate', 'Americano', 'Americano with Milk',
#        'Cocoa', 'Cortado', 'Espresso', 'Cappuccino'], dtype=object)

# %%
df['Weekdaysort'].unique()
# Out:
# array([5, 6, 7, 1, 2, 3, 4])

# %%
df['Time_of_Day'].unique()
# Out:
# array(['Morning', 'Afternoon', 'Night'], dtype=object)

# %%
df['Weekday'].unique()
# Out:
# array(['Fri', 'Sat', 'Sun', 'Mon', 'Tue', 'Wed', 'Thu'], dtype=object)

# %%
df['Month_name'].unique()
# Out:
# array(['Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov',
#        'Dec', 'Jan', 'Feb'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# hour_of_day    0
# cash_type      0
# money          0
# coffee_name    0
# Time_of_Day    0
# Weekday        0
# Month_name     0
# Weekdaysort    0
# Monthsort      0
# Date           0
# Time           0
# dtype: int64

# %%
df['cash_type'].value_counts()
# Out:
# cash_type
# Card    3547
# Name: count, dtype: int64

# %%
df['coffee_name'].value_counts()
# Out:
# coffee_name
# Americano with Milk    809
# Latte                  757
# Americano              564
# Cappuccino             486
# Cortado                287
# Hot Chocolate          276
# Cocoa                  239
# Espresso               129
# Name: count, dtype: int64

# %%
df.groupby("coffee_name")["money"].sum()
# Out:
# coffee_name
# Americano              14650.26
# Americano with Milk    24751.12
# Cappuccino             17439.14
# Cocoa                   8521.16
# Cortado                 7384.86
# Espresso                2690.28
# Hot Chocolate           9933.46
# Latte                  26875.30
# Name: money, dtype: float64

# %%
df.groupby('cash_type')['money'].sum()
# Out:
# cash_type
# Card    112245.58
# Name: money, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.title("Total sales by coffee type")
sns.barplot(x = 'coffee_name' , y = 'money' , data = df  ,hue = 'Time_of_Day')
plt.show()

# %%
monthly_earning = df.groupby(['Month_name' , 'Time_of_Day'])['money'].sum().reset_index()
week_day_earning = df.groupby(['Weekdaysort' , 'Time_of_Day'])['money'].sum().reset_index()

# %%
plt.figure(figsize=(12,7))
plt.title('Total sales by month')
sns.barplot(x = 'Month_name' , y = 'money' , data = monthly_earning , hue = 'Time_of_Day')
plt.xlabel('Month')
plt.ylabel("Total_earning")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = 'Weekdaysort' , y= 'money', data = week_day_earning  , hue = 'Time_of_Day')
plt.title("week_days_earning")
plt.xlabel("Days")
plt.ylabel('Total_sales')
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.countplot(x = 'hour_of_day', hue = 'coffee_name' ,data = df)
plt.title("Coffee Preferences by Hour of the Day")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Coffees Sold")
plt.show()

# %%
percentage_share = df.groupby('coffee_name')['money'].sum()
percentage_share
# Out:
# coffee_name
# Americano              14650.26
# Americano with Milk    24751.12
# Cappuccino             17439.14
# Cocoa                   8521.16
# Cortado                 7384.86
# Espresso                2690.28
# Hot Chocolate           9933.46
# Latte                  26875.30
# Name: money, dtype: float64

# %%
explode = [0.1 if value == percentage_share.max() else 0 for value in percentage_share]
plt.figure(figsize=(12,6))
plt.pie(percentage_share , labels = percentage_share.index , autopct = '%1.1f%%' , explode = explode , shadow = True)
plt.title('coffee sales share by type')
plt.show()

# %%
plt.figure(figsize = (8,4))
sns.lineplot(x = 'Month_name' , y = 'money' , data = monthly_earning , marker = 'o')
plt.title('Sales trends accross the months')
plt.xlabel('Month_Names')
plt.ylabel('Sales every month')
plt.grid()
plt.show()
